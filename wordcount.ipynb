# %%
#open file jabberwocky.txt as read
f = open ("jabberwocky.txt", "r")

# %%
#open warandpeace.txt as read
f = open("warandpeace.txt", "r")

# %%
import re

#create empty map for words to be added into
wordsfound = {}




#for loop of each line in file
for line in f:
    
    #variable listofwords to equal each word in line
    listofwords = line.split()
    #for loop going through listofwords
    for word in listofwords:
        #re.sub to remove punctuation from word
        word = re.sub('[^0-9a-zA-Z ]+', '', word)
        #put word to lower case so words with upper are not classed as separate words
        word = word.lower()
        #if word is already in map, add 1 to value of word otherwise set as 1
        if word in wordsfound:
            
            wordsfound[word] += 1
        else:
            wordsfound[word] = 1
#print wordsfound map
print(wordsfound)
#close file being read
f.close()
# Out:
# {'chapter': 367, 'i': 4089, 'well': 741, 'prince': 1886, 'so': 1852, 'genoa': 3, 'and': 22082, 'lucca': 2, 'are': 1259, 'now': 1305, 'just': 563, 'family': 135, 'estates': 38, 'of': 14872, 'the': 34395, 'buonapartes': 2, 'but': 4008, 'warn': 6, 'you': 3575, 'if': 1281, 'dont': 528, 'tell': 375, 'me': 1263, 'that': 7798, 'this': 2057, 'means': 70, 'war': 292, 'still': 667, 'try': 70, 'to': 16636, 'defend': 18, 'infamies': 1, 'horrors': 8, 'perpetrated': 3, 'by': 2379, 'antichristi': 2, 'really': 203, 'believe': 124, 'he': 9807, 'is': 3298, 'will': 1057, 'have': 1973, 'nothing': 462, 'more': 1052, 'do': 1033, 'with': 5648, 'no': 1394, 'longer': 176, 'my': 1220, 'friend': 163, 'faithful': 12, 'slave': 10, 'as': 3981, 'call': 91, 'yourself': 117, 'how': 991, 'see': 727, 'frightened': 117, 'yousit': 1, 'down': 690, 'all': 2754, 'news': 167, 'it': 5164, 'was': 7328, 'in': 8744, 'july': 13, '1805': 22, 'speaker': 14, 'wellknown': 16, 'anna': 293, 'pavlovna': 112, 'scherer': 6, 'maid': 58, '
# ...
